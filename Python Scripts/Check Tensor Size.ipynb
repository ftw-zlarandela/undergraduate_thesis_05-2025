# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/thesis/training_val_tensors
# Out:
# /content/drive/MyDrive/thesis/training_val_tensors

# %%
import cv2
import torch
import numpy as np

# %%
val_tensor = torch.load("akiyo_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("balcony_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("bowing_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("burn_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("carphone_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 144, 174])

# %%
val_tensor = torch.load("coastguard_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 288, 348])

# %%
val_tensor = torch.load("football1_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("football2_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([260, 1, 288, 346])

# %%
val_tensor = torch.load("foreman_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 288, 350])

# %%
val_tensor = torch.load("four_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("galleon_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("grandma_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 144, 176])

# %%
val_tensor = torch.load("hall_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 288, 352])

# %%
val_tensor = torch.load("intro_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("map_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("mobcal_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("mother_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 288, 338])

# %%
val_tensor = torch.load("ntsc_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("pamphlet_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 276, 352])

# %%
val_tensor = torch.load("parkjoy_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("parkrun_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("shields_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("silent_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 288, 348])

# %%
val_tensor = torch.load("sintel1_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("sintel2_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("sintel4_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("sintel5_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("stockholm_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("tempete_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([260, 1, 288, 352])

# %%
val_tensor = torch.load("tennis_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 240, 352])

# %%
val_tensor = torch.load("wind_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("window_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
cd /content/drive/MyDrive/thesis/testing_val_tensors
# Out:
# /content/drive/MyDrive/thesis/testing_val_tensors

# %%
val_tensor = torch.load("ducks_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("field_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("ice_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("life_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("news_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 288, 350])

# %%
val_tensor = torch.load("sign_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 288, 350])

# %%
val_tensor = torch.load("sintel3_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([300, 1, 1080, 1920])

# %%
val_tensor = torch.load("waterfall_val_tensor", weights_only=True)/255.0
print(val_tensor.shape)
del val_tensor
# Out:
# torch.Size([260, 1, 288, 344])
